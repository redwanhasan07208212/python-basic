# %%
import pandas as pd

# %%
ipl_df = pd.read_csv('ipl-matches.csv')

# %%
ipl_df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl_df = ipl_df.drop(columns=['method'])

# %%
ipl_df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl_df = ipl_df.drop(columns=['WinningTeam'])

# %%
ipl_df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl_df['City'] = ipl_df['City'].fillna(ipl_df['City'].mode()[0])
ipl_df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl_df.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
ipl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             950 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WonBy            950 non-null    object
#  12  Margin           932 non-null    float64
#  13  Player_of_Match  946 non-null    object
#  14  Team1Players     950 non-null    object
#  15  Team2Players     950 non-null    object
# ...

# %%
pd.to_datetime(ipl_df['Date'])
# Out:
# 0     2022-05-29
# 1     2022-05-27
# 2     2022-05-25
# 3     2022-05-24
# 4     2022-05-22
#          ...
# 945   2008-04-20
# 946   2008-04-20
# 947   2008-04-19
# 948   2008-04-19
# 949   2008-04-18
# Name: Date, Length: 950, dtype: datetime64[ns]

# %%
ipl_df['Date'] = pd.to_datetime(ipl_df['Date'])
ipl_df
# Out:
#           ID        City       Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad 2022-05-29     2022        Final
# 1    1312199   Ahmedabad 2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata 2022-05-25     2022   Eliminator
# 3    1312197     Kolkata 2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai 2022-05-22     2022           70
# ..       ...         ...        ...      ...          ...
# 945   335986     Kolkata 2008-04-20  2007/08            4
# 946   335985      Mumbai 2008-04-20  2007/08            5
# 947   335984       Delhi 2008-04-19  2007/08            3
# 948   335983  Chandigarh 2008-04-19  2007/08            2
# 949   335982   Bangalore 2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             950 non-null    object
#  2   Date             950 non-null    datetime64[ns]
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WonBy            950 non-null    object
#  12  Margin           932 non-null    float64
#  13  Player_of_Match  946 non-null    object
#  14  Team1Players     950 non-null    object
#  15  Team2Players     950 non-null    object
# ...

# %%
print(ipl_df['Date'].dt.year)
print(ipl_df['Date'].dt.month)
print(ipl_df['Date'].dt.day)
# Out:
# 0      2022
# 1      2022
# 2      2022
# 3      2022
# 4      2022
#        ...
# 945    2008
# 946    2008
# 947    2008
# 948    2008
# 949    2008
# Name: Date, Length: 950, dtype: int32
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 945    4
# 946    4
# 947    4
# 948    4
# 949    4
# Name: Date, Length: 950, dtype: int32
# 0      29
# 1      27
# 2      25
# 3      24
# 4      22
#        ..
# 945    20
# 946    20
# 947    19
# 948    19
# 949    18
# Name: Date, Length: 950, dtype: int32

# %%
print(ipl_df['Date'].dt.month_name())
print(ipl_df['Date'].dt.day_name())
# Out:
# 0        May
# 1        May
# 2        May
# 3        May
# 4        May
#        ...
# 945    April
# 946    April
# 947    April
# 948    April
# 949    April
# Name: Date, Length: 950, dtype: object
# 0         Sunday
# 1         Friday
# 2      Wednesday
# 3        Tuesday
# 4         Sunday
#          ...
# 945       Sunday
# 946       Sunday
# 947     Saturday
# 948     Saturday
# 949       Friday
# Name: Date, Length: 950, dtype: object

# %%
ipl_df['Month_Name'] = ipl_df['Date'].dt.month_name()
ipl_df['Day_Name'] = ipl_df['Date'].dt.day_name()

# %%
ipl_df.head()
# Out:
#         ID       City       Date Season  MatchNumber  \
# 0  1312200  Ahmedabad 2022-05-29   2022        Final
# 1  1312199  Ahmedabad 2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata 2022-05-25   2022   Eliminator
# 3  1312197    Kolkata 2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai 2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df = pd.DataFrame({"age":['24','34','unknown']})

# %%
df['age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3 entries, 0 to 2
# Series name: age
# Non-Null Count  Dtype
# --------------  -----
# 3 non-null      object
# dtypes: object(1)
# memory usage: 156.0+ bytes

# %%
df['age'] = pd.to_numeric(df['age'],errors='coerce')
print(df)
# Out:
#     age
# 0  24.0
# 1  34.0
# 2   NaN

# %%
df['age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3 entries, 0 to 2
# Series name: age
# Non-Null Count  Dtype
# --------------  -----
# 2 non-null      float64
# dtypes: float64(1)
# memory usage: 156.0 bytes

# %%
ipl_df.isnull().sum()
# Out:
# ID                  0
# City                0
# Date                0
# Season              0
# MatchNumber         0
# Team1               0
# Team2               0
# Venue               0
# TossWinner          0
# TossDecision        0
# SuperOver           4
# WonBy               0
# Margin             18
# Player_of_Match     4
# Team1Players        0
# Team2Players        0
# Umpire1             0
# Umpire2             0
# Month_Name          0
# Day_Name            0
# dtype: int64

# %%
ipl_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
ipl_df.drop_duplicates()
# Out:
#           ID        City       Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad 2022-05-29     2022        Final
# 1    1312199   Ahmedabad 2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata 2022-05-25     2022   Eliminator
# 3    1312197     Kolkata 2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai 2022-05-22     2022           70
# ..       ...         ...        ...      ...          ...
# 945   335986     Kolkata 2008-04-20  2007/08            4
# 946   335985      Mumbai 2008-04-20  2007/08            5
# 947   335984       Delhi 2008-04-19  2007/08            3
# 948   335983  Chandigarh 2008-04-19  2007/08            2
# 949   335982   Bangalore 2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl_df.describe()
# Out:
#                  ID                           Date      Margin
# count  9.500000e+02                            950  932.000000
# mean   8.304852e+05  2015-05-14 13:02:08.842105344   17.056867
# min    3.359820e+05            2008-04-18 00:00:00    1.000000
# 25%    5.012612e+05            2011-05-18 06:00:00    6.000000
# 50%    8.297380e+05            2015-04-20 12:00:00    8.000000
# 75%    1.175372e+06            2019-04-04 18:00:00   19.000000
# max    1.312200e+06            2022-05-29 00:00:00  146.000000
# std    3.375678e+05                            NaN   21.633109

# %%
ipl = pd.read_csv('ipl-matches.csv')

# %%
ipl.head(10)
# Out:
#         ID         City        Date Season  MatchNumber  \
# 0  1312200    Ahmedabad  2022-05-29   2022        Final
# 1  1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116       Mumbai  2022-05-22   2022           70
# 5  1304115       Mumbai  2022-05-21   2022           69
# 6  1304114       Mumbai  2022-05-20   2022           68
# 7  1304113       Mumbai  2022-05-19   2022           67
# 8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9  1304111       Mumbai  2022-05-17   2022           65
#
#                          Team1                        Team2  \
# 0             Rajasthan Royals               Gujarat Titans
# 1  Royal Challengers Bangalore             Rajasthan Royals
# 2  Royal Challengers Bangalore         Lucknow Super Giants
# 3             Rajasthan Royals               Gujarat Titans
# ...

# %%
final_winners = ipl[ipl['MatchNumber']== 'Final']
final_winners
# Out:
#           ID          City        Date   Season MatchNumber  \
# 0    1312200     Ahmedabad  2022-05-29     2022       Final
# 74   1254117         Dubai  2021-10-15     2021       Final
# 134  1237181           NaN  2020-11-10  2020/21       Final
# 194  1181768     Hyderabad  2019-05-12     2019       Final
# 254  1136620        Mumbai  2018-05-27     2018       Final
# 314  1082650     Hyderabad  2017-05-21     2017       Final
# 373   981019     Bangalore  2016-05-29     2016       Final
# 433   829823       Kolkata  2015-05-24     2015       Final
# 492   734049     Bangalore  2014-06-01     2014       Final
# 552   598073       Kolkata  2013-05-26     2013       Final
# 628   548381       Chennai  2012-05-27     2012       Final
# 702   501271       Chennai  2011-05-28     2011       Final
# 775   419165        Mumbai  2010-04-25  2009/10       Final
# 835   392239  Johannesburg  2009-05-24     2009       Final
# 892   336040        Mumbai  2008-06-01  2007/08       Final
#
# ...

# %%
final_winners[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
ipl.sample(10)
# Out:
#           ID        City        Date   Season MatchNumber  \
# 92   1254099   Abu Dhabi  2021-09-28     2021          42
# 370  1082593      Rajkot  2017-04-07     2017           3
# 284  1136590        Pune  2018-04-30     2018          30
# 326  1082638   Hyderabad  2017-05-08     2017          48
# 312  1136563     Kolkata  2018-04-08     2018           3
# 250  1175359      Jaipur  2019-03-25     2019           4
# 457   829775  Chandigarh  2015-05-03     2015          35
# 144  1216537   Abu Dhabi  2020-10-30  2020/21          50
# 428   980909     Kolkata  2016-04-13     2016           5
# 324  1082640      Kanpur  2017-05-10     2017          50
#
#                            Team1                  Team2  \
# 92                  Punjab Kings         Mumbai Indians
# 370                Gujarat Lions  Kolkata Knight Riders
# 284          Chennai Super Kings       Delhi Daredevils
# 326          Sunrisers Hyderabad         Mumbai Indians
# ...

# %%
superOver = ipl[ipl['SuperOver'] == 'Y']
superOver
# Out:
#           ID       City        Date   Season MatchNumber  \
# 114  1254077    Chennai  2021-04-25     2021          20
# 158  1216512  Abu Dhabi  2020-10-18  2020/21          35
# 159  1216517        NaN  2020-10-18  2020/21          36
# 184  1216547        NaN  2020-09-28  2020/21          10
# 192  1216493        NaN  2020-09-20  2020/21           2
# 203  1178426     Mumbai  2019-05-02     2019          51
# 244  1175365      Delhi  2019-03-30     2019          10
# 339  1082625     Rajkot  2017-04-29     2017          35
# 474   829741  Ahmedabad  2015-04-21     2015          18
# 533   729315  Abu Dhabi  2014-04-29     2014          19
# 608   598017  Bangalore  2013-04-16     2013          21
# 621   598004  Hyderabad  2013-04-07     2013           7
# 819   419121    Chennai  2010-03-21  2009/10          16
# 883   392190  Cape Town  2009-04-23     2009          10
#
#                            Team1                        Team2  \
# ...

# %%
ipl['SuperOver'].value_counts()
# Out:
# SuperOver
# N    932
# Y     14
# Name: count, dtype: int64

# %%
CSK_WON = ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')]
CSK_WON
# Out:
#           ID     City        Date   Season MatchNumber                  Team1  \
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision  \
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...

# %%
CSK_WON.shape
# Out:
# (5, 20)

# %%
CSK_WON.shape[0]
# Out:
# 5

# %%
ipl['Season'].unique()
# Out:
# array(['2022', '2021', '2020/21', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2009/10', '2009', '2007/08'],
#       dtype=object)

# %%
ipl['Venue'].nunique()
# Out:
# 49

# %%
ipl['Venue'].unique()
# Out:
# array(['Narendra Modi Stadium, Ahmedabad', 'Eden Gardens, Kolkata',
#        'Wankhede Stadium, Mumbai', 'Brabourne Stadium, Mumbai',
#        'Dr DY Patil Sports Academy, Mumbai',
#        'Maharashtra Cricket Association Stadium, Pune',
#        'Dubai International Cricket Stadium', 'Sharjah Cricket Stadium',
#        'Zayed Cricket Stadium, Abu Dhabi', 'Arun Jaitley Stadium, Delhi',
#        'MA Chidambaram Stadium, Chepauk, Chennai', 'Sheikh Zayed Stadium',
#        'Rajiv Gandhi International Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'MA Chidambaram Stadium',
#        'Punjab Cricket Association IS Bindra Stadium', 'Wankhede Stadium',
#        'M.Chinnaswamy Stadium', 'Arun Jaitley Stadium', 'Eden Gardens',
#        'Sawai Mansingh Stadium',
#        'Maharashtra Cricket Association Stadium',
#        'Holkar Cricket Stadium',
#        'Rajiv Gandhi International Stadium, Uppal',
# ...

# %%
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl.drop(columns='ID',inplace=True)

# %%
ipl.head()
# Out:
#         City        Date Season  MatchNumber                        Team1  \
# 0  Ahmedabad  2022-05-29   2022        Final             Rajasthan Royals
# 1  Ahmedabad  2022-05-27   2022  Qualifier 2  Royal Challengers Bangalore
# 2    Kolkata  2022-05-25   2022   Eliminator  Royal Challengers Bangalore
# 3    Kolkata  2022-05-24   2022  Qualifier 1             Rajasthan Royals
# 4     Mumbai  2022-05-22   2022           70          Sunrisers Hyderabad
#
#                   Team2                             Venue  \
# 0        Gujarat Titans  Narendra Modi Stadium, Ahmedabad
# 1      Rajasthan Royals  Narendra Modi Stadium, Ahmedabad
# 2  Lucknow Super Giants             Eden Gardens, Kolkata
# 3        Gujarat Titans             Eden Gardens, Kolkata
# 4          Punjab Kings          Wankhede Stadium, Mumbai
#
#              TossWinner TossDecision SuperOver                  WinningTeam  \
# 0      Rajasthan Royals          bat         N               Gujarat Titans
# ...

# %%
ipl.drop(columns=['Umpire1','Umpire2'],inplace=True)

# %%
ipl.head()
# Out:
#         City        Date Season  MatchNumber                        Team1  \
# 0  Ahmedabad  2022-05-29   2022        Final             Rajasthan Royals
# 1  Ahmedabad  2022-05-27   2022  Qualifier 2  Royal Challengers Bangalore
# 2    Kolkata  2022-05-25   2022   Eliminator  Royal Challengers Bangalore
# 3    Kolkata  2022-05-24   2022  Qualifier 1             Rajasthan Royals
# 4     Mumbai  2022-05-22   2022           70          Sunrisers Hyderabad
#
#                   Team2                             Venue  \
# 0        Gujarat Titans  Narendra Modi Stadium, Ahmedabad
# 1      Rajasthan Royals  Narendra Modi Stadium, Ahmedabad
# 2  Lucknow Super Giants             Eden Gardens, Kolkata
# 3        Gujarat Titans             Eden Gardens, Kolkata
# 4          Punjab Kings          Wankhede Stadium, Mumbai
#
#              TossWinner TossDecision SuperOver                  WinningTeam  \
# 0      Rajasthan Royals          bat         N               Gujarat Titans
# ...

# %%
data = {

    'City':["NY","Mumbai", "Paris", "NY", "Mumbai", "Mumbai", "Paris"],
    'Temperature':[23, 34, 21, 30, 36,37,21]

}

# %%
df3 = pd.DataFrame(data)

# %%
df3
# Out:
#      City  Temperature
# 0      NY           23
# 1  Mumbai           34
# 2   Paris           21
# 3      NY           30
# 4  Mumbai           36
# 5  Mumbai           37
# 6   Paris           21

# %%
city = df3.groupby('City')

# %%
city['Temperature'].mean()
# Out:
# City
# Mumbai    35.666667
# NY        26.500000
# Paris     21.000000
# Name: Temperature, dtype: float64

# %%
df3.groupby('City')['Temperature'].mean()
# Out:
# City
# Mumbai    35.666667
# NY        26.500000
# Paris     21.000000
# Name: Temperature, dtype: float64

# %%
df3.groupby('City')['Temperature'].max()
# Out:
# City
# Mumbai    37
# NY        30
# Paris     21
# Name: Temperature, dtype: int64

# %%
df3.groupby('City')['Temperature'].min()
# Out:
# City
# Mumbai    34
# NY        23
# Paris     21
# Name: Temperature, dtype: int64

# %%
df3.groupby('City')['Temperature'].sum()
# Out:
# City
# Mumbai    107
# NY         53
# Paris      42
# Name: Temperature, dtype: int64

# %%
df3.groupby('City')['Temperature'].count()
# Out:
# City
# Mumbai    3
# NY        2
# Paris     2
# Name: Temperature, dtype: int64

# %%
data2 = {

    'City':["NY","Mumbai", "Paris", "NY", "Mumbai", "Mumbai", "Paris"],
    'Temperature':[23, 34, 21, 30, 36,37,21],
    'WindSpeed':[54, 34, 65, 32, 43, 47, 31]
}

# %%
df2 = pd.DataFrame(data2)

# %%
df2.groupby('City')[['Temperature','WindSpeed']].agg(['mean','max','min'])
# Out:
#        Temperature          WindSpeed
#               mean max min       mean max min
# City
# Mumbai   35.666667  37  34  41.333333  47  34
# NY       26.500000  30  23  43.000000  54  32
# Paris    21.000000  21  21  48.000000  65  31

# %%
data3 = {

    'City':["NY","Mumbai", "Paris", "NY", "Mumbai", "Mumbai", "Paris"],
    'Temperature':[23, 34, 21, 30, 36,37,21],
    'WindSpeed':[54, 34, 65, 32, 43, 47, 31],
    'Event':['Sunny', 'Rainy', 'Cloudy','Sunny', 'Rainy', 'Cloudy','Sunny']

}

# %%
df4 = pd.DataFrame(data3)

# %%
df4
# Out:
#      City  Temperature  WindSpeed   Event
# 0      NY           23         54   Sunny
# 1  Mumbai           34         34   Rainy
# 2   Paris           21         65  Cloudy
# 3      NY           30         32   Sunny
# 4  Mumbai           36         43   Rainy
# 5  Mumbai           37         47  Cloudy
# 6   Paris           21         31   Sunny

# %%
df4.groupby(['City','Event'])[['Temperature','WindSpeed']].agg(['mean','max','min'])
# Out:
#               Temperature         WindSpeed
#                      mean max min      mean max min
# City   Event
# Mumbai Cloudy        37.0  37  37      47.0  47  47
#        Rainy         35.0  36  34      38.5  43  34
# NY     Sunny         26.5  30  23      43.0  54  32
# Paris  Cloudy        21.0  21  21      65.0  65  65
#        Sunny         21.0  21  21      31.0  31  31

# %%
temp_df = pd.DataFrame({
'City': ['New York', 'Chicago', 'Orlando'],
'Temperature': [32, 30, 35]
})

humidity_df = pd.DataFrame({
'City': ['Chicago', 'New York', 'San Diego'],
'Humidity': [60, 65, 70]
})

# %%
print(temp_df)
print(humidity_df)
# Out:
#        City  Temperature
# 0  New York           32
# 1   Chicago           30
# 2   Orlando           35
#         City  Humidity
# 0    Chicago        60
# 1   New York        65
# 2  San Diego        70

# %%
df = pd.merge(temp_df,humidity_df, on='City')
df
# Out:
#        City  Temperature  Humidity
# 0  New York           32        65
# 1   Chicago           30        60

# %%
df = pd.merge(temp_df,humidity_df,on='City',how='outer')
df
# Out:
#         City  Temperature  Humidity
# 0    Chicago         30.0      60.0
# 1   New York         32.0      65.0
# 2    Orlando         35.0       NaN
# 3  San Diego          NaN      70.0

# %%
df = pd.merge(temp_df,humidity_df,on='City',how='left')
df
# Out:
#        City  Temperature  Humidity
# 0  New York           32      65.0
# 1   Chicago           30      60.0
# 2   Orlando           35       NaN

# %%
df = pd.merge(temp_df,humidity_df,on='City',how='right')
df
# Out:
#         City  Temperature  Humidity
# 0    Chicago         30.0        60
# 1   New York         32.0        65
# 2  San Diego          NaN        70

# %%
bang_weather = pd.DataFrame({
'City': ['Dhaka', 'Rajshahi', 'Chittagong'],
'Temperature': [34, 39, 42]
})

us_weather = pd.DataFrame({
'City': ['New York', 'Chicago', 'Orlando'],
'Temperature': [32, 30, 35]
})

# %%
print(bang_weather)
print(us_weather)
# Out:
#          City  Temperature
# 0       Dhaka           34
# 1    Rajshahi           39
# 2  Chittagong           42
#        City  Temperature
# 0  New York           32
# 1   Chicago           30
# 2   Orlando           35

# %%
df = pd.merge(bang_weather,us_weather,on='City',how='outer')
df
# Out:
#          City  Temperature_x  Temperature_y
# 0     Chicago            NaN           30.0
# 1  Chittagong           42.0            NaN
# 2       Dhaka           34.0            NaN
# 3    New York            NaN           32.0
# 4     Orlando            NaN           35.0
# 5    Rajshahi           39.0            NaN

# %%
df = pd.concat([us_weather,bang_weather])
df
# Out:
#          City  Temperature
# 0    New York           32
# 1     Chicago           30
# 2     Orlando           35
# 0       Dhaka           34
# 1    Rajshahi           39
# 2  Chittagong           42

# %%
bang_weather['Country'] = 'Bangladesh'
us_weather['Country'] = 'United States'

# %%
pd.concat([bang_weather,us_weather],ignore_index=True)
# Out:
#          City  Temperature        Country
# 0       Dhaka           34     Bangladesh
# 1    Rajshahi           39     Bangladesh
# 2  Chittagong           42     Bangladesh
# 3    New York           32  United States
# 4     Chicago           30  United States
# 5     Orlando           35  United States

# %%
nov = pd.read_csv('reg-month1.csv')
dec = pd.read_csv('reg-month2.csv')

# %%
nov
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
dec
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
multi = pd.concat([nov,dec],keys=['November','December'])
multi
# Out:
#              student_id  course_id
# November 0           23          1
#          1           15          5
#          2           18          6
#          3           23          4
#          4           16          9
#          5           18          1
#          6            1          1
#          7            7          8
#          8           22          3
#          9           15          1
#          10          19          4
#          11           1          6
#          12           7         10
#          13          11          7
#          14          13          3
#          15          24          4
#          16          21          1
#          17          16          5
#          18          23          3
#          19          17          7
#          20          23          6
#          21          25          1
#          22          19          2
#          23          25         10
#          24           3          3
# December 0            3          5
# ...
