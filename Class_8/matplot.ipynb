# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
price = [48000,54000,57000,49000,47000,45000]
year = [2015,2016,2017,2018,2019,2020]

plt.plot(year,price)
plt.show()

# %%
plt.figure(figsize=(16,8))
price = [48000,54000,57000,49000,47000,45000]
year = [2015,2016,2017,2018,2019,2020]

plt.plot(year,price)
plt.show()

# %%
import pandas as pd 
import numpy as np

# %%
data1 = pd.read_excel('linechart.xlsx',sheet_name='product sales')
data1.head()
# Out:
#    Quarter  Fridge  Dishwasher  Washing Machine
# 0  Q1 2022    12.5         8.0              9.2
# 1  Q2 2022    11.0         7.5              8.5
# 2  Q3 2022    13.2         9.0              7.5
# 3  Q4 2022    16.4        11.0              7.6
# 4  Q1 2023    13.8         9.5              6.8

# %%
plt.figure(figsize=(16,6))
plt.plot(data1['Quarter'],data1['Dishwasher'],label = 'DishWasher Sales',color='red')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.plot(data1['Quarter'],data1['Dishwasher'], label = 'Dishwasher Sales' , color = "red" , marker = 'o')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.plot(data1['Quarter'],data1['Dishwasher'],label = 'Dishwasher Sales', color = 'red', marker='o', markersize = 8,linewidth = 2 , markerfacecolor = 'black' , markeredgecolor = 'black' , linestyle = '--' )
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.plot(data1['Quarter'],data1['Dishwasher'],label = 'Dishwasher Sales',color='red',marker='o',markersize=8,linewidth=2,markerfacecolor = 'black')
plt.legend()
plt.title('Dishwasher Sales over Quarter')
plt.xlabel('Quarter',fontsize = 16)
plt.ylabel('Sales Amount',fontsize=16)
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.plot(
    data1['Quarter'],
    data1['Dishwasher'],
    label='Dishwasher Sales',
    color='red',
    marker='o',
    markersize=8,
    linewidth=2,
    markerfacecolor='black'
)


# Add grid
plt.grid(True, linestyle='--', alpha=0.5)

# Set background color
plt.gca().set_facecolor('#f9f9f9')  # light gray background
plt.gcf().patch.set_facecolor('white')  # figure background

# Title and labels
plt.title('📈 Dishwasher Sales Over Quarters', fontsize=20, fontweight='bold')
plt.xlabel('Quarter', fontsize=14)
plt.ylabel('Sales Amount', fontsize=14)

# Customize ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Show legend
plt.legend(fontsize=12)


plt.show()

# %%
plt.figure(figsize=(16, 6))

# Plotting with simple enhancements
plt.plot(data1["Quarter"],
         data1["Dishwasher"],
         label="Dishwasher Sales",
         color="red",
         linewidth=2.5,
         marker="o",
         markersize=8,
         markerfacecolor="white",
         markeredgecolor="black",
         )


# Setting a black background color
plt.gca().set_facecolor('black')
plt.gcf().set_facecolor('black')

# Titles and labels
plt.title('Dishwasher Sales Over Quarters', fontsize=18,color="white")
plt.xlabel('Quarter', fontsize=14,color="white")
plt.ylabel('Sales Amount', fontsize=14,color="white")

# Show grid for readability
plt.grid(True, linestyle=':', alpha=0.4)

# Add legend
plt.legend(fontsize=12)


# Show the plot
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(data1['Quarter'],data1['Dishwasher'],marker='o',color='red',linestyle='-',label='Dishwasher Sales')
plt.plot(data1['Quarter'],data1['Fridge'],marker='o',color='cyan',linestyle='-',label='Fridge Sales')
plt.plot(data1['Quarter'],data1['Washing Machine'],marker='o',color='green',linestyle='-',label='Washing Machine')

plt.title('Dishwasher, Fridge and Washing Machine Sales Over Quarters')
plt.xlabel('Quarter',fontsize=14,color='black')
plt.ylabel('Sales Amount',fontsize=14,color='black')
plt.grid(True,linestyle=':',alpha=0.4)
plt.legend(fontsize=10)
plt.tight_layout()
plt.show()

# %%
data = pd.read_csv('generated_tips_data.csv')
tips = pd.DataFrame(data)
tips.head()
# Out:
#    total_bill   tip     sex smoker   day    time  size
# 0       24.98  1.28    Male     No  Thur   Lunch     4
# 1       48.03  6.73    Male     No  Thur   Lunch     3
# 2       39.28  3.83  Female     No  Thur   Lunch     1
# 3       33.95  5.58    Male    Yes   Fri  Dinner     4
# 4       16.24  9.17    Male    Yes   Fri   Lunch     4

# %%
plt.scatter(tips['total_bill'],tips['tip'])

# %%
plt.scatter(tips['total_bill'],tips['tip'],s=tips['size']*20)

# %%
plt.scatter(tips['total_bill'],tips['tip'],s=tips['tip']*10)

# %%
plt.scatter(
    tips['total_bill'],
    tips['tip'],
    s=tips['tip']*10,
    c=tips['sex'].map({'Male':'blue','Female':'red'}),
    alpha=0.4
)
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.title('Scatter plot of Tip vs Total Bill')
plt.show()
